# %% [markdown]
# *Última atualização: 29.02.2024*
#
# Siga: @caionosdados | @rdseyhat
#
# ---

# %% [markdown]
# # Este repositório tem como objetivo ser um guia de matemática contendo principalmente conceitos e exemplos mostrados em código, alguns materiais foram retirados das seguintes fontes:
#
# - 📕Um Convite a matemática
# - Wikipedia (pesquisas sobre as áreas)
# - 📕Essencial Math For Data Science
# - Khan Academy
# - Universidade Dos Dados
# - Kaggle Learning
#
# entre outros

# %% [markdown]
# # A notação matemática
#
# É um conjunto de símbolos que representa um objeto ou uma idéia. Construídos com letras do alfabeto ou figuras.

# %% [markdown]
# ## Tabela de Notações
#
#
# ![image.png](data:image/png;base64,...)
